# %% [markdown]
# Connected to .venv (3.11.13) (Python 3.11.13)

# %%
from torch.utils.data import TensorDataset, DataLoader
from sklearn.metrics import roc_auc_score
import torch.optim as optim
from deepsea import DeepSEA
from data import X, Y
import torch.nn as nn
import torch
import math

X_tensor = torch.from_numpy(X).float().permute(0, 2, 1)
Y_tensor = torch.from_numpy(Y).float()

# positional split: first 80% train, last 20% val
split = int(0.8 * len(X_tensor))
X_train, X_val = X_tensor[:split], X_tensor[split:]
Y_train, Y_val = Y_tensor[:split], Y_tensor[split:]

train_loader = DataLoader(TensorDataset(X_train, Y_train), batch_size=128, shuffle=True)
val_loader   = DataLoader(TensorDataset(X_val,   Y_val),   batch_size=512, shuffle=False)

device    = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model     = DeepSEA(n_outputs=5).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer, mode='min', factor=0.5, patience=3, min_lr=1e-6
)
criterion = nn.BCEWithLogitsLoss()

marks = ['H3k4me1', 'H3k4me3', 'H3k27ac', 'DNase', 'CTCF']

print(f"Device: {device}")
print(f"Train samples: {len(X_train):,} | Val samples: {len(X_val):,}")
print(f"Train batches: {len(train_loader)} | Val batches: {len(val_loader)}")
print("-" * 80)

best_val_loss = math.inf
log_interval  = max(1, len(train_loader) // 5)  # print ~5 times per epoch

for epoch in range(30):
    # --- train ---
    model.train()
    train_loss   = 0.0
    batches_seen = 0
    for batch_idx, (xb, yb) in enumerate(train_loader):
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        loss = criterion(model(xb), yb)
        loss.backward()
        optimizer.step()
        train_loss   += loss.item() * len(xb)
        batches_seen += 1

        if (batch_idx + 1) % log_interval == 0:
            running_loss = train_loss / (batches_seen * train_loader.batch_size)
            pct = 100.0 * (batch_idx + 1) / len(train_loader)
            print(f"  Epoch {epoch+1:>2d} [{pct:5.1f}%] batch {batch_idx+1}/{len(train_loader)} "
                  f"| running loss {running_loss:.4f}")

    train_loss /= len(X_train)

    # --- validate ---
    model.eval()
    all_logits, all_labels = [], []
    with torch.no_grad():
        for xb, yb in val_loader:
            all_logits.append(model(xb.to(device)).cpu())
            all_labels.append(yb)
    logits = torch.cat(all_logits)
    labels = torch.cat(all_labels)

    val_loss = criterion(logits, labels).item()
    probs    = torch.sigmoid(logits).numpy()

    aurocs = []
    for i in range(5):
        try:
            aurocs.append(roc_auc_score(labels[:, i], probs[:, i]))
        except ValueError:
            aurocs.append(float('nan'))   # fires if val split has no positives for a mark

    mean_auroc = sum(a for a in aurocs if not math.isnan(a)) / sum(1 for a in aurocs if not math.isnan(a))

    scheduler.step(val_loss)
    current_lr = optimizer.param_groups[0]['lr']

    print(f"Epoch {epoch+1:>2d} | train {train_loss:.4f} | val {val_loss:.4f} | "
          f"mean AUROC {mean_auroc:.3f} | lr {current_lr:.2e} | "
          + " ".join(f"{m}={a:.3f}" for m, a in zip(marks, aurocs)))

    # --- checkpoint ---
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save({
            'epoch':      epoch + 1,
            'state_dict': model.state_dict(),
            'optimizer':  optimizer.state_dict(),
            'val_loss':   val_loss,
            'aurocs':     dict(zip(marks, aurocs)),
        }, 'best_model.pt')
        print(f"  --> Saved checkpoint (val loss improved to {val_loss:.4f})")

print("-" * 80)
print(f"Training complete. Best val loss: {best_val_loss:.4f} | checkpoint: best_model.pt")
# Out:
# Loaded 5 ENCODE peak files
# chr21: 48,129,895 bp
#   windows so far: 27,558
# chr22: 49,396,972 bp
#   windows so far: 64,007
# X shape: (64007, 1000, 4) Y shape: (64007, 5)
# positives per mark:
#   H3k4me1    51777  (80.9%)
#   H3k4me3    33054  (51.6%)
#   H3k27ac    23429  (36.6%)
#   DNase       6809  (10.6%)
#   CTCF        2191  (3.4%)
# Device: cpu
# Train samples: 51,205 | Val samples: 12,802
# Train batches: 401 | Val batches: 26
# --------------------------------------------------------------------------------
#   Epoch  1 [ 20.0%] batch 80/401 | running loss 0.5677
#   Epoch  1 [ 39.9%] batch 160/401 | running loss 0.5200
#   Epoch  1 [ 59.9%] batch 240/401 | running loss 0.5027
#   Epoch  1 [ 79.8%] batch 320/401 | running loss 0.4942
#   Epoch  1 [ 99.8%] batch 400/401 | running loss 0.4884
# Epoch  1 | train 0.4884 | val 0.5735 | mean AUROC 0.495 | lr 1.00e-03 | H3k4me1=0.489 H3k4me3=0.495 H3k27ac=0.497 DNase=0.496 CTCF=0.497
#   --> Saved checkpoint (val loss improved to 0.5735)
#   Epoch  2 [ 20.0%] batch 80/401 | running loss 0.4765
#   Epoch  2 [ 39.9%] batch 160/401 | running loss 0.4700
#   Epoch  2 [ 59.9%] batch 240/401 | running loss 0.4670
#   Epoch  2 [ 79.8%] batch 320/401 | running loss 0.4666
#   Epoch  2 [ 99.8%] batch 400/401 | running loss 0.4661
# Epoch  2 | train 0.4661 | val 0.4565 | mean AUROC 0.495 | lr 1.00e-03 | H3k4me1=0.497 H3k4me3=0.501 H3k27ac=0.499 DNase=0.489 CTCF=0.489
#   --> Saved checkpoint (val loss improved to 0.4565)
#   Epoch  3 [ 20.0%] batch 80/401 | running loss 0.4615
#   Epoch  3 [ 39.9%] batch 160/401 | running loss 0.4605
#   Epoch  3 [ 59.9%] batch 240/401 | running loss 0.4622
#   Epoch  3 [ 79.8%] batch 320/401 | running loss 0.4629
#   Epoch  3 [ 99.8%] batch 400/401 | running loss 0.4638
# Epoch  3 | train 0.4638 | val 0.4578 | mean AUROC 0.494 | lr 1.00e-03 | H3k4me1=0.501 H3k4me3=0.502 H3k27ac=0.501 DNase=0.483 CTCF=0.485
#   Epoch  4 [ 20.0%] batch 80/401 | running loss 0.4645
#   Epoch  4 [ 39.9%] batch 160/401 | running loss 0.4631
#   Epoch  4 [ 59.9%] batch 240/401 | running loss 0.4627
#   Epoch  4 [ 79.8%] batch 320/401 | running loss 0.4621
#   Epoch  4 [ 99.8%] batch 400/401 | running loss 0.4619
# Epoch  4 | train 0.4619 | val 0.4602 | mean AUROC 0.493 | lr 1.00e-03 | H3k4me1=0.497 H3k4me3=0.501 H3k27ac=0.503 DNase=0.482 CTCF=0.480
#   Epoch  5 [ 20.0%] batch 80/401 | running loss 0.4644
#   Epoch  5 [ 39.9%] batch 160/401 | running loss 0.4630
#   Epoch  5 [ 59.9%] batch 240/401 | running loss 0.4615
#   Epoch  5 [ 79.8%] batch 320/401 | running loss 0.4620
#   Epoch  5 [ 99.8%] batch 400/401 | running loss 0.4610
# Epoch  5 | train 0.4610 | val 0.4490 | mean AUROC 0.493 | lr 1.00e-03 | H3k4me1=0.488 H3k4me3=0.497 H3k27ac=0.503 DNase=0.491 CTCF=0.487
#   --> Saved checkpoint (val loss improved to 0.4490)
#   Epoch  6 [ 20.0%] batch 80/401 | running loss 0.4643
#   Epoch  6 [ 39.9%] batch 160/401 | running loss 0.4608
#   Epoch  6 [ 59.9%] batch 240/401 | running loss 0.4604
#   Epoch  6 [ 79.8%] batch 320/401 | running loss 0.4603
#   Epoch  6 [ 99.8%] batch 400/401 | running loss 0.4601
# Epoch  6 | train 0.4601 | val 0.4513 | mean AUROC 0.491 | lr 1.00e-03 | H3k4me1=0.488 H3k4me3=0.494 H3k27ac=0.507 DNase=0.482 CTCF=0.482
#   Epoch  7 [ 20.0%] batch 80/401 | running loss 0.4559
#   Epoch  7 [ 39.9%] batch 160/401 | running loss 0.4578
#   Epoch  7 [ 59.9%] batch 240/401 | running loss 0.4578
#   Epoch  7 [ 79.8%] batch 320/401 | running loss 0.4590
#   Epoch  7 [ 99.8%] batch 400/401 | running loss 0.4588
# Epoch  7 | train 0.4588 | val 0.4519 | mean AUROC 0.491 | lr 1.00e-03 | H3k4me1=0.487 H3k4me3=0.496 H3k27ac=0.500 DNase=0.493 CTCF=0.479
#   Epoch  8 [ 20.0%] batch 80/401 | running loss 0.4595
#   Epoch  8 [ 39.9%] batch 160/401 | running loss 0.4590
#   Epoch  8 [ 59.9%] batch 240/401 | running loss 0.4586
#   Epoch  8 [ 79.8%] batch 320/401 | running loss 0.4595
#   Epoch  8 [ 99.8%] batch 400/401 | running loss 0.4585
# Epoch  8 | train 0.4585 | val 0.4566 | mean AUROC 0.493 | lr 1.00e-03 | H3k4me1=0.495 H3k4me3=0.500 H3k27ac=0.501 DNase=0.493 CTCF=0.475
#   Epoch  9 [ 20.0%] batch 80/401 | running loss 0.4611
#   Epoch  9 [ 39.9%] batch 160/401 | running loss 0.4600
#   Epoch  9 [ 59.9%] batch 240/401 | running loss 0.4582
#   Epoch  9 [ 79.8%] batch 320/401 | running loss 0.4574
#   Epoch  9 [ 99.8%] batch 400/401 | running loss 0.4570
# Epoch  9 | train 0.4570 | val 0.4572 | mean AUROC 0.490 | lr 5.00e-04 | H3k4me1=0.485 H3k4me3=0.497 H3k27ac=0.507 DNase=0.497 CTCF=0.464
#   Epoch 10 [ 20.0%] batch 80/401 | running loss 0.4547
#   Epoch 10 [ 39.9%] batch 160/401 | running loss 0.4542
#   Epoch 10 [ 59.9%] batch 240/401 | running loss 0.4540
#   Epoch 10 [ 79.8%] batch 320/401 | running loss 0.4537
#   Epoch 10 [ 99.8%] batch 400/401 | running loss 0.4535
# Epoch 10 | train 0.4535 | val 0.4563 | mean AUROC 0.493 | lr 5.00e-04 | H3k4me1=0.485 H3k4me3=0.500 H3k27ac=0.507 DNase=0.498 CTCF=0.475
#   Epoch 11 [ 20.0%] batch 80/401 | running loss 0.4484
#   Epoch 11 [ 39.9%] batch 160/401 | running loss 0.4513
#   Epoch 11 [ 59.9%] batch 240/401 | running loss 0.4518
#   Epoch 11 [ 79.8%] batch 320/401 | running loss 0.4518
#   Epoch 11 [ 99.8%] batch 400/401 | running loss 0.4518
# Epoch 11 | train 0.4518 | val 0.4618 | mean AUROC 0.492 | lr 5.00e-04 | H3k4me1=0.479 H3k4me3=0.505 H3k27ac=0.507 DNase=0.485 CTCF=0.485
#   Epoch 12 [ 20.0%] batch 80/401 | running loss 0.4529
#   Epoch 12 [ 39.9%] batch 160/401 | running loss 0.4528
#   Epoch 12 [ 59.9%] batch 240/401 | running loss 0.4519
#   Epoch 12 [ 79.8%] batch 320/401 | running loss 0.4513
#   Epoch 12 [ 99.8%] batch 400/401 | running loss 0.4506
# Epoch 12 | train 0.4506 | val 0.4601 | mean AUROC 0.490 | lr 5.00e-04 | H3k4me1=0.490 H3k4me3=0.497 H3k27ac=0.503 DNase=0.485 CTCF=0.476
#   Epoch 13 [ 20.0%] batch 80/401 | running loss 0.4436
#   Epoch 13 [ 39.9%] batch 160/401 | running loss 0.4471
#   Epoch 13 [ 59.9%] batch 240/401 | running loss 0.4478
#   Epoch 13 [ 79.8%] batch 320/401 | running loss 0.4476
#   Epoch 13 [ 99.8%] batch 400/401 | running loss 0.4478
# Epoch 13 | train 0.4478 | val 0.4613 | mean AUROC 0.492 | lr 2.50e-04 | H3k4me1=0.480 H3k4me3=0.499 H3k27ac=0.506 DNase=0.486 CTCF=0.489
#   Epoch 14 [ 20.0%] batch 80/401 | running loss 0.4446
#   Epoch 14 [ 39.9%] batch 160/401 | running loss 0.4435
#   Epoch 14 [ 59.9%] batch 240/401 | running loss 0.4432
#   Epoch 14 [ 79.8%] batch 320/401 | running loss 0.4443
#   Epoch 14 [ 99.8%] batch 400/401 | running loss 0.4446
# Epoch 14 | train 0.4446 | val 0.4648 | mean AUROC 0.491 | lr 2.50e-04 | H3k4me1=0.484 H3k4me3=0.497 H3k27ac=0.510 DNase=0.483 CTCF=0.481
#   Epoch 15 [ 20.0%] batch 80/401 | running loss 0.4386
#   Epoch 15 [ 39.9%] batch 160/401 | running loss 0.4406
#   Epoch 15 [ 59.9%] batch 240/401 | running loss 0.4423
#   Epoch 15 [ 79.8%] batch 320/401 | running loss 0.4412
#   Epoch 15 [ 99.8%] batch 400/401 | running loss 0.4418
# Epoch 15 | train 0.4418 | val 0.4669 | mean AUROC 0.494 | lr 2.50e-04 | H3k4me1=0.482 H3k4me3=0.502 H3k27ac=0.518 DNase=0.488 CTCF=0.480
#   Epoch 16 [ 20.0%] batch 80/401 | running loss 0.4400
#   Epoch 16 [ 39.9%] batch 160/401 | running loss 0.4388
#   Epoch 16 [ 59.9%] batch 240/401 | running loss 0.4397
#   Epoch 16 [ 79.8%] batch 320/401 | running loss 0.4398
#   Epoch 16 [ 99.8%] batch 400/401 | running loss 0.4397
# Epoch 16 | train 0.4396 | val 0.4654 | mean AUROC 0.498 | lr 2.50e-04 | H3k4me1=0.492 H3k4me3=0.503 H3k27ac=0.507 DNase=0.489 CTCF=0.497
#   Epoch 17 [ 20.0%] batch 80/401 | running loss 0.4416
#   Epoch 17 [ 39.9%] batch 160/401 | running loss 0.4394
#   Epoch 17 [ 59.9%] batch 240/401 | running loss 0.4378
#   Epoch 17 [ 79.8%] batch 320/401 | running loss 0.4377
#   Epoch 17 [ 99.8%] batch 400/401 | running loss 0.4369
# Epoch 17 | train 0.4369 | val 0.4693 | mean AUROC 0.495 | lr 1.25e-04 | H3k4me1=0.494 H3k4me3=0.499 H3k27ac=0.503 DNase=0.490 CTCF=0.489
#   Epoch 18 [ 20.0%] batch 80/401 | running loss 0.4372
#   Epoch 18 [ 39.9%] batch 160/401 | running loss 0.4330
#   Epoch 18 [ 59.9%] batch 240/401 | running loss 0.4329
#   Epoch 18 [ 79.8%] batch 320/401 | running loss 0.4317
#   Epoch 18 [ 99.8%] batch 400/401 | running loss 0.4324
# Epoch 18 | train 0.4324 | val 0.4713 | mean AUROC 0.499 | lr 1.25e-04 | H3k4me1=0.479 H3k4me3=0.503 H3k27ac=0.511 DNase=0.493 CTCF=0.507
#   Epoch 19 [ 20.0%] batch 80/401 | running loss 0.4317
#   Epoch 19 [ 39.9%] batch 160/401 | running loss 0.4312
#   Epoch 19 [ 59.9%] batch 240/401 | running loss 0.4319
#   Epoch 19 [ 79.8%] batch 320/401 | running loss 0.4315
#   Epoch 19 [ 99.8%] batch 400/401 | running loss 0.4307
# Epoch 19 | train 0.4307 | val 0.4758 | mean AUROC 0.496 | lr 1.25e-04 | H3k4me1=0.488 H3k4me3=0.500 H3k27ac=0.508 DNase=0.488 CTCF=0.494
#   Epoch 20 [ 20.0%] batch 80/401 | running loss 0.4280
#   Epoch 20 [ 39.9%] batch 160/401 | running loss 0.4263
#   Epoch 20 [ 59.9%] batch 240/401 | running loss 0.4267
